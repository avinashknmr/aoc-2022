# %%
with open('../input/D02.txt', 'r') as f:
    data = [l.replace(' ','') for l in f.read().splitlines()]
data
# Out:
# ['AY',
#  'BY',
#  'BZ',
#  'BZ',
#  'AY',
#  'CY',
#  'AY',
#  'CY',
#  'AY',
#  'BX',
#  'BY',
#  'BZ',
#  'AY',
#  'AY',
#  'CY',
#  'CY',
#  'AY',
#  'CY',
#  'BY',
#  'AY',
#  'AY',
#  'CY',
#  'CX',
#  'AY',
#  'BZ',
#  'CY',
#  'AY',
#  'CY',
#  'AY',
#  'CY',
#  'AZ',
#  'AY',
#  'CY',
#  'BY',
#  'AY',
#  'CY',
#  'BX',
#  'BZ',
#  'CX',
#  'BZ',
#  'BX',
#  'CY',
#  'BZ',
#  'AY',
#  'CY',
#  'BX',
#  'AY',
#  'AZ',
#  'BY',
#  'CY',
#  'AX',
#  'CX',
#  'CY',
#  'CY',
#  'AY',
#  'CX',
#  'AY',
#  'CX',
#  'CY',
#  'CY',
#  'AY',
#  'CY',
#  'AZ',
#  'AY',
#  'BZ',
#  'AY',
#  'AY',
#  'BX',
#  'AY',
#  'BY',
#  'AY',
#  'BX',
#  'BY',
#  'CY',
#  'AY',
#  'BX',
#  'AY',
#  'CX',
#  'BY',
#  'AY',
#  'BZ',
#  'CY',
#  'CY',
#  'BY',
#  'BZ',
#  'BZ',
#  'BY',
#  'BY',
#  'AY',
#  'AY',
#  'AZ',
#  'CY',
#  'BX',
#  'AY',
#  'BY',
#  'AY',
#  'BX',
#  'CY',
#  'AZ',
#  'CY',
#  'CY',
#  'AY',
#  'AY',
#  'CY',
#  'CY',
#  'BX',
#  'AY',
#  'AY',
#  'BX',
#  'AY',
#  'CY',
# ...

# %%
opp_move_score = {'A': 1, 'B': 2, 'C': 3}
my_move_score = {'X': 1, 'Y': 2, 'Z': 3}
total_score = 0
game_rules = {'AX':3, 'BX': 0, 'CX': 6, 'AY': 6, 'BY': 3, 'CY': 0, 'AZ': 0, 'BZ': 6, 'CZ': 3}

for g in data:
    game_point = game_rules[g]
    total_score += my_move_score[g[1]] + game_point
total_score
# Out:
# 13565

# %%
game_point = {'X': 0, 'Y': 3, 'Z': 6}
my_move_score = {'A': 1, 'B': 2, 'C': 3}

total_score = 0
my_strategy = {'AX': 'C', 'BX': 'A', 'CX': 'B', 'AY': 'A', 'BY': 'B', 'CY': 'C', 'AZ': 'B', 'BZ': 'C', 'CZ': 'A'}

for g in data:
    my_move = my_strategy[g]
    total_score += game_point[g[1]] + my_move_score[my_move]
total_score
# Out:
# 12424
